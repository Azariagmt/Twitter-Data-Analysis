# %% [markdown]
# <a href="https://colab.research.google.com/github/Azariagmt/Twitter-Data-Analysis/blob/main/notebooks/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# nltk package contains stop words we'll remove using regular expressions
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Read in the document-term matrix
import pandas as pd

data_clean = pd.read_pickle('data_clean.pkl')
dtm = pd.read_pickle('dtm.pkl')

# %%
from wordcloud import WordCloud

wc = WordCloud(stopwords=stop, background_color="white", colormap="Dark2",
               max_font_size=150, random_state=42)

# %%
# Reset the output dimensions
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [16, 6]

wc.generate(' '.join(data_clean['clean_text']))

plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.title("Word clouds")
    
plt.show()

# %%
data_clean = data_clean[data_clean['clean_text']!="nan"]

# %%
data_clean.shape
# Out:
# (2248, 5)

# %%
# Reset the output dimensions
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [16, 6]

wc.generate(' '.join(data_clean['clean_text']))

plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.title("Word clouds")
    
plt.show()
